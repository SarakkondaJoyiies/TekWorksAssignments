# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("C://Users//Proxy1//Desktop//6682-COE//high_popularity_spotify_data.csv")

# %%
print(df.head())
# Out:
#    energy    tempo  danceability playlist_genre  loudness  liveness  valence  \
# 0   0.592  157.969         0.521            pop    -7.777     0.122    0.535
# 1   0.507  104.978         0.747            pop   -10.171     0.117      NaN
# 2   0.808  108.548         0.554            pop    -4.169     0.159    0.372
# 3   0.910  112.966         0.670            pop    -4.070     0.304    0.786
# 4   0.783  149.027         0.777            pop    -4.477     0.355    0.939
#
#             track_artist  time_signature  speechiness  ...  instrumentalness  \
# 0  Lady Gaga, Bruno Mars             3.0       0.0304  ...            0.0000
# 1          Billie Eilish             4.0       0.0358  ...            0.0608
# 2          Gracie Abrams             4.0       0.0368  ...            0.0000
# 3      Sabrina Carpenter             4.0       0.0634  ...            0.0000
# 4       ROSÉ, Bruno Mars             4.0       0.2600  ...            0.0000
#
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1686 entries, 0 to 1685
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   energy                    1685 non-null   float64
#  1   tempo                     1686 non-null   float64
#  2   danceability              1686 non-null   float64
#  3   playlist_genre            1685 non-null   object
#  4   loudness                  1685 non-null   float64
#  5   liveness                  1686 non-null   float64
#  6   valence                   1685 non-null   float64
#  7   track_artist              1685 non-null   object
#  8   time_signature            1685 non-null   float64
#  9   speechiness               1685 non-null   float64
#  10  track_popularity          1686 non-null   int64
#  11  track_href                1682 non-null   object
#  12  uri                       1680 non-null   object
# ...

# %%
print(df.shape)
# Out:
# (1686, 29)

# %%
print(df.columns)
# Out:
# Index(['energy', 'tempo', 'danceability', 'playlist_genre', 'loudness',
#        'liveness', 'valence', 'track_artist', 'time_signature', 'speechiness',
#        'track_popularity', 'track_href', 'uri', 'track_album_name',
#        'playlist_name', 'analysis_url', 'track_id', 'track_name',
#        'track_album_release_date', 'instrumentalness', 'track_album_id',
#        'mode', 'key', 'duration_ms', 'acousticness', 'id', 'playlist_subgenre',
#        'type', 'playlist_id'],
#       dtype='object')

# %%
print(df.iloc[10:20,0:3])
# Out:
#     energy    tempo  danceability
# 10   0.667  130.019         0.776
# 11   0.586  107.071         0.669
# 12   0.806  104.032         0.608
# 13   0.709   81.012         0.722
# 14   0.757  139.982         0.742
# 15   0.917  100.987         0.562
# 16   0.787  109.939         0.734
# 17   0.843  122.064         0.619
# 18   0.406  115.940         0.530
# 19   0.782  119.992         0.727

# %%
print(df.isnull())
# Out:
#       energy  tempo  danceability  playlist_genre  loudness  liveness  \
# 0      False  False         False           False     False     False
# 1      False  False         False           False     False     False
# 2      False  False         False           False     False     False
# 3      False  False         False           False     False     False
# 4      False  False         False           False     False     False
# ...      ...    ...           ...             ...       ...       ...
# 1681   False  False         False           False     False     False
# 1682   False  False         False           False     False     False
# 1683   False  False         False           False     False     False
# 1684   False  False         False           False     False     False
# 1685   False  False         False           False     False     False
#
#       valence  track_artist  time_signature  speechiness  ...  \
# 0       False         False           False        False  ...
# ...

# %%
print(df['playlist_genre'])
# Out:
# 0         pop
# 1         pop
# 2         pop
# 3         pop
# 4         pop
#         ...
# 1681    latin
# 1682    latin
# 1683    latin
# 1684    latin
# 1685      pop
# Name: playlist_genre, Length: 1686, dtype: object

# %%
print(df.iloc[:,3])
# Out:
# 0         pop
# 1         pop
# 2         pop
# 3         pop
# 4         pop
#         ...
# 1681    latin
# 1682    latin
# 1683    latin
# 1684    latin
# 1685      pop
# Name: playlist_genre, Length: 1686, dtype: object

# %%
print(df['playlist_genre'].unique())
# Out:
# ['pop' nan 'rock' 'jazz' 'classical' 'hip-hop' 'afrobeats' 'latin'
#  'indian' 'country' 'r&b' 'electronic' 'soul' 'gaming' 'j-pop' 'metal'
#  'reggae' 'k-pop' 'arabic' 'punk' 'blues' 'folk' 'lofi' 'brazilian'
#  'turkish' 'ambient' 'korean' 'world' 'indie']

# %%
print(df.dropna())
# Out:
#       energy    tempo  danceability playlist_genre  loudness  liveness  \
# 0      0.592  157.969         0.521            pop    -7.777    0.1220
# 2      0.808  108.548         0.554            pop    -4.169    0.1590
# 3      0.910  112.966         0.670            pop    -4.070    0.3040
# 4      0.783  149.027         0.777            pop    -4.477    0.3550
# 5      0.582  116.712         0.700            pop    -5.960    0.0881
# ...      ...      ...           ...            ...       ...       ...
# 1681   0.422  124.357         0.573          latin    -7.621    0.1020
# 1682   0.725  105.016         0.711          latin    -8.315    0.1100
# 1683   0.809   99.005         0.724          latin    -5.022    0.0765
# 1684   0.642   83.389         0.463          latin    -4.474    0.0686
# 1685   0.890  126.881         0.645            pop    -4.985    0.3760
#
#       valence               track_artist  time_signature  speechiness  ...  \
# ...

# %%
print(df.describe())
# Out:
#             energy        tempo  danceability     loudness     liveness  \
# count  1685.000000  1686.000000   1686.000000  1685.000000  1686.000000
# mean      0.667161   121.070938      0.650362    -6.699626     0.171579
# std       0.184949    27.066029      0.157721     3.373000     0.123953
# min       0.001610    49.305000      0.136000   -43.643000     0.021000
# 25%       0.551000   100.058750      0.543250    -7.918000     0.093400
# 50%       0.689000   120.001000      0.664500    -5.973000     0.121000
# 75%       0.807000   136.833500      0.769000    -4.686000     0.210000
# max       0.990000   209.688000      0.979000     1.295000     0.950000
#
#            valence  time_signature  speechiness  track_popularity  \
# count  1685.000000     1685.000000  1685.000000       1686.000000
# mean      0.525789        3.950148     0.100962         75.806050
# std       0.236174        0.326767     0.099767          6.032532
# ...

# %%
print(df['liveness'].max())
# Out:
# 0.95

# %%
print(df['liveness'].min())
# Out:
# 0.021

# %%
df.rename(columns={"track_name":"track_title"})
# Out:
#       energy    tempo  danceability playlist_genre  loudness  liveness  \
# 0      0.592  157.969         0.521            pop    -7.777    0.1220
# 1      0.507  104.978         0.747            pop   -10.171    0.1170
# 2      0.808  108.548         0.554            pop    -4.169    0.1590
# 3      0.910  112.966         0.670            pop    -4.070    0.3040
# 4      0.783  149.027         0.777            pop    -4.477    0.3550
# ...      ...      ...           ...            ...       ...       ...
# 1681   0.422  124.357         0.573          latin    -7.621    0.1020
# 1682   0.725  105.016         0.711          latin    -8.315    0.1100
# 1683   0.809   99.005         0.724          latin    -5.022    0.0765
# 1684   0.642   83.389         0.463          latin    -4.474    0.0686
# 1685   0.890  126.881         0.645            pop    -4.985    0.3760
#
#       valence               track_artist  time_signature  speechiness  ...  \
# ...

# %%
df.rename(columns={"energy":"energy_level"})
# Out:
#       energy_level    tempo  danceability playlist_genre  loudness  liveness  \
# 0            0.592  157.969         0.521            pop    -7.777    0.1220
# 1            0.507  104.978         0.747            pop   -10.171    0.1170
# 2            0.808  108.548         0.554            pop    -4.169    0.1590
# 3            0.910  112.966         0.670            pop    -4.070    0.3040
# 4            0.783  149.027         0.777            pop    -4.477    0.3550
# ...            ...      ...           ...            ...       ...       ...
# 1681         0.422  124.357         0.573          latin    -7.621    0.1020
# 1682         0.725  105.016         0.711          latin    -8.315    0.1100
# 1683         0.809   99.005         0.724          latin    -5.022    0.0765
# 1684         0.642   83.389         0.463          latin    -4.474    0.0686
# 1685         0.890  126.881         0.645            pop    -4.985    0.3760
#
# ...

# %%
print(df["energy"].mean())
# Out:
# 0.6671610089020771

# %%
print(df["energy"].mode())
# Out:
# 0    0.586
# Name: energy, dtype: float64

# %%
print(df["energy"].median())
# Out:
# 0.689

# %%
print(df["energy"].std())
# Out:
# 0.18494884326352498

# %%
print(df.isna())
# Out:
#       energy  tempo  danceability  playlist_genre  loudness  liveness  \
# 0      False  False         False           False     False     False
# 1      False  False         False           False     False     False
# 2      False  False         False           False     False     False
# 3      False  False         False           False     False     False
# 4      False  False         False           False     False     False
# ...      ...    ...           ...             ...       ...       ...
# 1681   False  False         False           False     False     False
# 1682   False  False         False           False     False     False
# 1683   False  False         False           False     False     False
# 1684   False  False         False           False     False     False
# 1685   False  False         False           False     False     False
#
#       valence  track_artist  time_signature  speechiness  ...  \
# 0       False         False           False        False  ...
# ...

# %%
null_values=df.isnull()
filled_values=df.fillna('NA')
print(filled_values)
# Out:
#      energy    tempo  danceability playlist_genre loudness  liveness valence  \
# 0     0.592  157.969         0.521            pop   -7.777    0.1220   0.535
# 1     0.507  104.978         0.747            pop  -10.171    0.1170      NA
# 2     0.808  108.548         0.554            pop   -4.169    0.1590   0.372
# 3      0.91  112.966         0.670            pop    -4.07    0.3040   0.786
# 4     0.783  149.027         0.777            pop   -4.477    0.3550   0.939
# ...     ...      ...           ...            ...      ...       ...     ...
# 1681  0.422  124.357         0.573          latin   -7.621    0.1020   0.693
# 1682  0.725  105.016         0.711          latin   -8.315    0.1100    0.53
# 1683  0.809   99.005         0.724          latin   -5.022    0.0765   0.606
# 1684  0.642   83.389         0.463          latin   -4.474    0.0686   0.339
# 1685   0.89  126.881         0.645            pop   -4.985    0.3760   0.421
#
# ...

# %%
filled_values=df.fillna('Unknown')
print(filled_values)
# Out:
#      energy    tempo  danceability playlist_genre loudness  liveness  valence  \
# 0     0.592  157.969         0.521            pop   -7.777    0.1220    0.535
# 1     0.507  104.978         0.747            pop  -10.171    0.1170  Unknown
# 2     0.808  108.548         0.554            pop   -4.169    0.1590    0.372
# 3      0.91  112.966         0.670            pop    -4.07    0.3040    0.786
# 4     0.783  149.027         0.777            pop   -4.477    0.3550    0.939
# ...     ...      ...           ...            ...      ...       ...      ...
# 1681  0.422  124.357         0.573          latin   -7.621    0.1020    0.693
# 1682  0.725  105.016         0.711          latin   -8.315    0.1100     0.53
# 1683  0.809   99.005         0.724          latin   -5.022    0.0765    0.606
# 1684  0.642   83.389         0.463          latin   -4.474    0.0686    0.339
# 1685   0.89  126.881         0.645            pop   -4.985    0.3760    0.421
#
# ...

# %%
print(df.dtypes)
# Out:
# energy                      float64
# tempo                       float64
# danceability                float64
# playlist_genre               object
# loudness                    float64
# liveness                    float64
# valence                     float64
# track_artist                 object
# time_signature              float64
# speechiness                 float64
# track_popularity              int64
# track_href                   object
# uri                          object
# track_album_name             object
# playlist_name                object
# analysis_url                 object
# track_id                     object
# track_name                   object
# track_album_release_date     object
# instrumentalness            float64
# track_album_id               object
# mode                          int64
# key                           int64
# duration_ms                   int64
# acousticness                float64
# id                           object
# ...

# %%
print(df.T)
# Out:
#                                                                        0     \
# energy                                                                0.592
# tempo                                                               157.969
# danceability                                                          0.521
# playlist_genre                                                          pop
# loudness                                                             -7.777
# liveness                                                              0.122
# valence                                                               0.535
# track_artist                                          Lady Gaga, Bruno Mars
# time_signature                                                          3.0
# speechiness                                                          0.0304
# track_popularity                                                        100
# ...

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=1686, step=1)
